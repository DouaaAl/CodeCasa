# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_cards = pd.read_csv('creditcard.csv' ,encoding='latin1')
credit_cards.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_cards.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
credit_cards.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_cards.shape
# Out:
# (284807, 31)

# %%
credit_cards['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
real_credit_cards = credit_cards[credit_cards['Class'] == 0].sample(n=492)
fake_credit_cards = credit_cards[credit_cards['Class'] == 1]

# %%
credit_cards = pd.concat([real_credit_cards, fake_credit_cards], axis=0)

# %%
credit_cards.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 143416   85339.0 -3.647980  2.712487 -1.792369 -1.618985 -1.731273 -0.052051
# 270776  164246.0  2.086635  0.109571 -1.339058  0.318940  0.169284 -1.250080
# 266376  162304.0 -3.135885  1.709995 -2.339310 -0.035475 -0.505860  0.146074
# 9120     12869.0  1.163525  0.160521  0.702450  0.720948 -0.397333 -0.304689
# 97950    66455.0  1.315404 -0.033577 -1.089984 -0.557087  2.029931  3.268130
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 143416 -1.892076  2.985514  0.053621  ... -0.031129 -0.532564  0.213952
# 270776  0.357261 -0.483071  0.378026  ...  0.252407  0.972829 -0.035971
# 266376 -0.516621  2.034752 -0.937649  ...  0.587453  1.147330 -0.232080
# 9120   -0.312961  0.074251  1.285991  ... -0.333462 -0.791914  0.209833
# 97950  -0.534994  0.808250 -0.052724  ... -0.313307 -1.068934  0.103797
#
# ...

# %%
credit_cards.Class.value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %% [raw]
# x = credit_cards.drop('Class', axis=1)
# x

# %%
y = credit_cards['Class']
y
# Out:
# 143416    0
# 270776    0
# 266376    0
# 9120      0
# 97950     0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=2)

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# C:\Users\ACH\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
x_predict = model.predict(x_test)
test_acc = accuracy_score(x_predict, y_test)
test_acc
# Out:
# 0.9238578680203046
